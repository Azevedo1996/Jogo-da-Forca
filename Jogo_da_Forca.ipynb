# %% [markdown]
# <a href="https://colab.research.google.com/github/Azevedo1996/Jogo-da-Forca/blob/main/Jogo_da_Forca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Projeto Forca
import random


# Saudações
print("#"*40 + "\n      Bem vindo(a) ao Jogo da Forca\n" + "#"*40, "\n")

nome = str(input("Qual seu nome? "))
nome = nome.capitalize()

#Listas de palavras.
fruta = ["abacate", "abacaxi", "acerola", "manga", "cupuacu", "melancia", "banana"]
paisesAmericaDoSul = ["brasil", "argentina", "colombia", "chile", "venezuela", "equador" ]
paisesAmericaDoNorte = ["estados unidos", "canada", "mexico"]
paisesEuropa = ["inglaterra", "portugal", "italia", "grecia", "irlanda", "alemanha"]


#Letras de descobertas durante o jogo.
letrasDescobertas = []

#Letras acertadas pelo jogador1 referentes a palavra digitada pelo jogador2
Acertos = []

#Palavra digitada pelo jogador, quando o jogo é em dupla.
palavraDigitadaJogador = []

#Opção para iniciar o contador do While
opcao = 0

#Contador para o jogo contra parceiro
erros = 0

#Função para mostrar o boneco do jogo de Forca
def desenho(erros):
    if erros == 0:
        print()
        print("|----- ")
        print("|    | ")
        print("|      ")
        print("|      ")
        print("|      ")
        print("|      ")
        print("_      ")
        print()


    elif erros == 1:
        print()
        print("|----- ")
        print("|    | ")
        print("|    O  ")
        print("|      ")
        print("|      ")
        print("|      ")
        print("_      ")
        print()

    elif erros == 2:
        print()
        print("|----- ")
        print("|    | ")
        print("|    O  ")
        print("|    | ")
        print("|      ")
        print("|      ")
        print("_      ")
        print()


    elif erros == 3:
        print()
        print("|----- ")
        print("|    | ")
        print("|    O  ")
        print("|   /|  ")
        print("|      ")
        print("|      ")
        print("_      ")
        print()


    elif erros == 4:
        print()
        print("|----- ")
        print("|    | ")
        print("|    O  ")
        print("|   /|\ ")
        print("|      ")
        print("|      ")
        print("_      ")
        print()


    elif erros == 5:
        print()
        print("|----- ")
        print("|    | ")
        print("|    O  ")
        print("|   /|\\  ")
        print("|    | ")
        print("|      ")
        print("_      ")
        print()


    elif erros == 6:
        print()
        print("|----- ")
        print("|    | ")
        print("|    O  ")
        print("|   /|\\  ")
        print("|    |  ")
        print("|   /  ")
        print("_      ")
        print()


    elif erros == 7:
        print()
        print("|----- ")
        print("|    | ")
        print("|    O ")
        print("|   /|\\ ")
        print("|    | ")
        print("|   / \\ ")
        print("_      ")
        print()


#Função jogo opção fruta
def modoJogoOp1():
    robot = random.choice(fruta)
    q = ''
    x = ' , '
    letrasDescobertas.clear()
    # print(q.join(robot))#teste para saber se esta funcionando corretamente de acordo com a palavra pseudo-aleatoria
    erros = 0
    desenho(erros)

    for i in range(0, len(robot)):
        letrasDescobertas.append("_")
    #print(letrasDescobertas[i])
    # print(" ".join(letrasDescobertas)) # imprimir a lista na horizontal
 
    acertou = False

    while acertou == False:
        letra = str(input(f"{nome},digite uma letra: "))
        desenho(erros)
        
        for i in range(0, len(robot)):
            if letra == robot[i]:
                letrasDescobertas[i] = letra                           
                print(letrasDescobertas) 
                
        acertou = True

        for x in range(0, len(letrasDescobertas)):
            if letrasDescobertas[x] == "_":
                acertou = False
            
            
#Função jogo opção america do sul          
def modoJogoOp2():
    robot = random.choice(paisesAmericaDoSul)
    q = ''
    x = ' , '
    letrasDescobertas.clear()
    print(q.join(robot))#teste para saber se esta funcionando corretamente de acordo com a palavra pseudo-aleatoria
    erros = 0
    desenho(erros)

    for i in range(0, len(robot)):
        letrasDescobertas.append("_")
    #print(letrasDescobertas[i])
    print(" ".join(letrasDescobertas)) # imprimir a lista na horizontal
 
    acertou = False

    while acertou == False:
        letra = str(input(f"{nome},digite uma letra: "))
        desenho(erros)
        
        for i in range(0, len(robot)):
            if letra == robot[i]:
                letrasDescobertas[i] = letra                           
                print(letrasDescobertas) 
                
        acertou = True

        for x in range(0, len(letrasDescobertas)):
            if letrasDescobertas[x] == "_":
                acertou = False
            
            
                
def modoJogoOp3():
    robot = random.choice(paisesEuropa)
    q = ''
    x = ' , '
    letrasDescobertas.clear()
    print(q.join(robot))#teste para saber se esta funcionando corretamente de acordo com a palavra pseudo-aleatoria
    erros = 0
    desenho(erros)

    for i in range(0, len(robot)):
        letrasDescobertas.append("_")
    #print(letrasDescobertas[i])
    print(" ".join(letrasDescobertas)) # imprimir a lista na horizontal
 
    acertou = False

    while acertou == False:
        letra = str(input(f"{nome},digite uma letra: "))
        desenho(erros)
        
        for i in range(0, len(robot)):
            if letra == robot[i]:
                letrasDescobertas[i] = letra                           
                print(letrasDescobertas) 
                
        acertou = True

        for x in range(0, len(letrasDescobertas)):
            if letrasDescobertas[x] == "_":
                acertou = False
            
            
def modoJogoOp4():    
    robot = random.choice(paisesAmericaDoNorte)
    q = ''
    x = ' , '
    letrasDescobertas.clear()
    print(q.join(robot))#teste para saber se esta funcionando corretamente de acordo com a palavra pseudo-aleatoria
    erros = 0
    desenho(erros)

    for i in range(0, len(robot)):
        letrasDescobertas.append("_")
    #print(letrasDescobertas[i])
    print(" ".join(letrasDescobertas)) # imprimir a lista na horizontal
 
    acertou = False

    while acertou == False:
        letra = str(input(f"{nome},digite uma letra: "))
        desenho(erros)
        
        for i in range(0, len(robot)):
            if letra == robot[i]:
                letrasDescobertas[i] = letra                           
                print(letrasDescobertas) 
                
        acertou = True

        for x in range(0, len(letrasDescobertas)):
            if letrasDescobertas[x] == "_":
                acertou = False
            
            

                
#Menu principal, para escolher se jogará sozinho ou em dupla.
while opcao != 3:
    print("[1] Para jogar contra a maquina.\n"
          "[2] Para jogar com parceiro.\n"
          "[3] Se quiser sair. ")
    opcao = int(input(f"{nome}, qual a opção desejada? "))

# Quando for jogar sozinho opção pelo tema.
    if opcao == 1:
        while opcao != 5:
            print("[1] Frutas.\n"
                  "[2] Países da America do Sul.\n"
                  "[3] Paises Europa.\n"
                  "[4] Países da America do Norte.\n"
                  "[5] Se quiser sair. ")
            opcao = int(input(f"{nome}, qual tema deseja jogar? "))

# Tema de Fruta
            if opcao == 1:
                modoJogoOp1()

# Tema de Paises da America do Sul 
            elif opcao == 2:
                modoJogoOp2()
                
# Tema de Paises da Europa
            elif opcao == 3:
                modoJogoOp3()
                            
# Tema de Paises da America do Norte
            elif opcao == 4:
                modoJogoOp4()
                            
                            
    # Jogando com um parceiro
    if opcao == 2:
        
#nome do parceiro
        jogador2 = str(input("Qual nome do seu parceiro? "))
        jogador2 = jogador2.capitalize()

# pedido do parceiro digitar uma palavra
        
        robot = input(f"{jogador2}, digite uma palavra: ")
        #print(robot)
        palavraDigitadaJogador = list(robot)
        q = ''
        x = ' , '
        #print(q.join(robot))#teste para saber se esta funcionando corretamente de acordo com a palavra pseudo-aleatoria
        letrasDescobertas.clear()
        erros = 0
        desenho(erros)
        
        
# Inicio do jogo com parceiro 

        for i in palavraDigitadaJogador:
             letrasDescobertas.append("_")
        print(" ".join(letrasDescobertas))


        acertou = False

        while acertou == False:
            letra = str(input(f"{nome},digite uma letra: "))
            erros += 1
            desenho(erros)
            if erros == 7: 
                break
                           
            for i in range(0, len(palavraDigitadaJogador)):
                if letra == palavraDigitadaJogador[i]:
                    letrasDescobertas[i] = letra                           
                    print(letrasDescobertas)
            acertou = True

            for x in range(0, len(letrasDescobertas)):
                if letrasDescobertas[x] == "_":
                    acertou = False



                        
# Fim do jogo
    elif opcao == 3:
        print("Fim do jogo, Volte sempre!")

                            

# Saída do Jogo
    else:
        print("Fim do jogo, Volte sempre!")
# Out:
# ########################################
#       Bem vindo(a) ao Jogo da Forca
# ########################################
#
# Qual seu nome? Leonardo
# [1] Para jogar contra a maquina.
# [2] Para jogar com parceiro.
# [3] Se quiser sair.
# Leonardo, qual a opção desejada? 1
# [1] Frutas.
# [2] Países da America do Sul.
# [3] Paises Europa.
# [4] Países da America do Norte.
# [5] Se quiser sair.
# Leonardo, qual tema deseja jogar? 1
# banana
#
# |-----
# |    |
# |
# |
# |
# |
# _
#
# _ _ _ _ _ _
# Leonardo,digite uma letra: a
#
# |-----
# |    |
# |
# |
# |
# |
# _
#
# ['_', 'a', '_', '_', '_', '_']
# ['_', 'a', '_', 'a', '_', '_']
# ['_', 'a', '_', 'a', '_', 'a']
# Leonardo,digite uma letra: b
#
# |-----
# |    |
# |
# |
# |
# |
# _
#
# ['b', 'a', '_', 'a', '_', 'a']
# Leonardo,digite uma letra: n
#
# |-----
# |    |
# |
# |
# |
# |
# _
#
# ['b', 'a', 'n', 'a', '_', 'a']
# ['b', 'a', 'n', 'a', 'n', 'a']
# [1] Frutas.
# [2] Países da America do Sul.
# [3] Paises Europa.
# ...
